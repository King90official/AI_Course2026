# %% [markdown]
# <a href="https://colab.research.google.com/github/King90official/AI_Course2026/blob/main/first%20program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# generate random data
data = np.random.randn(1000)

plt.hist(data, bins=30, color='purple', edgecolor='black')
plt.title ("My AI Enviroment is working")
plt.show()
